# %%
# In Python it is standard practice to import the modules 
# we need at the very top of our scripts
import numpy as np

# %% [markdown]
# # Assigning and Using Variables
#
# Programming languages use variables (names) to refer to objects, such as numbers, that you will use over again. In Python, variables are assigned with the `=` symbol, e.g. `a = 3`.
#
# Variables can hold almost anything, but we will usually use them to store a number (or an array of multiple numbers). Python and Numpy both have their own data types, some of which we will cover in this course.
# Once defined, the variable `a` can be used over and over again (see the cell below).
# Variables can be used to store information but you can also do calculations with variables, e.g. `c = a+b`, just like you would with numbers.
#
# ## Printing Variables
#
# We may want to check on the value stored in a variable. We can do this using the `print()` function. It is also possible to print out some text (text is referred to in programming as a "string"). You can write a string by surrounding your text with quotation marks. Run the cell below to see all this in action.
#
# ## Comments
# You will have noticed that the example code often contains *comments* (which start with the `#` character). You can write any text you want after the `#` character and that text will not be treated like a program to be run. It is just an informative comment for the benefit of you and anybody else reading your code. Good code contains comments that explain what the surrounding code is doing (e.g. 'calculate the length of the hypotenuse', and (for more complex code) the higher-level *purpose* of a whole larger chunk of code (e.g. 'Integrate over a circle using Simpson's rule')

# %%
# Create two new variables 'a' and 'b' and assign them integer values
a = 2
b = 3

# Print 'a' and 'b'
print(a, b)

# Update 'a' and print out 'a' and 'b' again. Note that the value printed for 'a' has changed
a = 4
print(a, b)

# Better: print out a string of text in order to make it clearer what the numbers actually mean
print('The value of a is', a)
print('The value of b is', b)
# Out:
# 2 3
# 4 3
# The value of a is 4
# The value of b is 3

# %% [markdown]
# Now edit the cell below, to write some code that assigns the product of `a` and `b` to a new variable `c`, and then print `a`, `b` and `c`.

# %%
# Write your Python here
# assuming that we want to do comments for this bit and redefine a and b

# whitespace is important in Python so look, _whitespace_

#define a and b
a = 2
b = 3

#calculate product of a and b, where product is a new variable "c"
c = a * b

#disp all var
print('The value of a is', a)
print('The value of b is', b)
print('The value of c is', c)

#or we could have used the print function to calculate the product of a and b without creating a new variable
# print('The product of a and b is', a * b)
# or we could have used the print f string to calculate the product of a and b without creating a new variable
#print(f'The product of a and b is {a * b}')
# or even , well you get the idea...
# Out:
# The value of a is 2
# The value of b is 3
# The value of c is 6

# %% [markdown]
# ## Formatted Printing
#
# We can mix text and numbers in a much more sophisticated way, which is helpful for generating readable output from your code. This is done by using the `.format()` method on a string of text. We will not discuss all the details this piece of relatively advanced syntax, but you should learn from examples like the ones below, and make use of them in the code you write in figure. Throughout this course (and others) you should make sure you are printing your answers to an appropriate number of significant figures, based on the significant figures of the inputs that you have been given.

# %%
a = 1.2222223
b = np.pi

# Print the variables on their own (to more significant figures than are probably appropriate for your calculation)
print(a, b)

# With supporting text (still too many significant figures):
print('Variable a: {0}; Pi: {1}'.format(a,b))
# Note that {0} refers to the first variable you list after 'format' (i.e. a in this case),
# {1} refers to the second variable (i.e. b in this case), etc.

# To two decimal places:
print('Variable a (2 d.p.): {0:.2f}; Pi: {1:.2f}'.format(a,b))

# To one significant figure:
print('Variable a (1 sig fig): {0:.1g}; Pi: {1:.1g}'.format(a,b))
# Out:
# 1.2222223 3.141592653589793
# Variable a: 1.2222223; Pi: 3.141592653589793
# Variable a (2 d.p.): 1.22; Pi: 3.14
# Variable a (1 sig fig): 1; Pi: 3

# %% [markdown]
# ## Errors and Debugging
# Inevitably we will make mistakes when writing our code. Try running the cell below, and you will see that it does not work. The process of fixing your own code so that it runs successfully, and gives the correct answers, is known as *debugging*.
#
# Can you see what these common mistakes are, and debug the code so the cell runs successfully? Edit the comments to record what the error message was and what needed to be fixed

# %% [markdown]
# #### Complete this cell after debugging and fixing the code in the next cell:
# This line originally read: `c = a + b / 2)`
#
# This resulted in an error that said: "Cell In[7], line 1 c = a + b / 2) <font color=red> SyntaxError: unmatched</font> ')'"
#
# This was because we closed a non opened bracket, and I fixed it by opening the bracket at b

# %%
c = a + (b / 2)

# %% [markdown]
# #### Complete this cell after debugging and fixing the code in the next cell:
# The first line originally read: `c = a + (b / 2`
#
# This resulted in an error that said: "Cell In[9], line 1 c = a + (b / 2 SyntaxError: '(' was never closed." This was because we did not close a bracket we opened and I fixed it by closing the bracket This error was a bit misleading because ???! (what?)
#
# <br>
#
# The second line originally read: `c = a + z`
#
# This resulted in an error that said: nothing because the line had not yet been executed, bu would have said that z is undefined.  This was because we used Z and I fixed it by ???

# %%
c = a + (b / 2)

c = a + z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 c = a + (b / 2)
#       2
# ----> 3 c = a + z
#
# NameError: name 'z' is not defined

# %% [markdown]
# #### Complete this cell after debugging and fixing the code in the next cell:
# This line originally read `c = arccos(a)`
#
# This resulted in an error: Name Error as we do not define arc cos, This was because we failed to reference the numpy lib and I fixed it by adding np (and defining a)

# %%
c = np.arccos(a)
# Out:
# /var/folders/cw/gm_1zsb50fg6y7t9lct0ctr80000gn/T/ipykernel_3221/139748001.py:1: RuntimeWarning: invalid value encountered in arccos
#   c = np.arccos(a)

# %% [markdown]
# #### Complete this cell after debugging and fixing the code in the next cell:
#
# This line originally read `c = np.asin(a)`
#
# This resulted in an error: ????. This was because ???, and I fixed it by ???

# %%
c = np.asin(a)
# Out:
# /var/folders/cw/gm_1zsb50fg6y7t9lct0ctr80000gn/T/ipykernel_3221/806269538.py:1: RuntimeWarning: invalid value encountered in arcsin
#   c = np.asin(a)

# %% [markdown]
# #### Complete this cell after debugging and fixing the code in the next cell:
#
# This line originally read `1stValue = a*2`
#
# This resulted in an error: syntax This was because it is a decimal mix var name and I fixed it by renaming the var to firstValue

# %%
firstValue = a*2

# %% [markdown]
# Not all mistakes are identified by the Python programming language as an error! Always think about the numbers your code is outputting: do they seem plausible? Can you check them by hand, for a simple example case?
#
# #### Complete this cell after debugging and fixing the code in the next cell:
#
# This line originally read `hypotenuse = np.sqrt(a**2) + b**2`
#
# This did not result in an error, but was incorrect because sqrt did not address the b term and so it was added on un square rooted we must thus change the para to cover the whole terms.

# %%
hypotenuse = np.sqrt(a**2 + b**2)
print('A right-angled triangle with sides of length {0:.2f} and {1:.2f} has a hypotenuse of length {2:.2f}'.format(a, b, hypotenuse))
# Out:
# A right-angled triangle with sides of length 1.22 and 3.14 has a hypotenuse of length 3.37

# %% [markdown]
# # Exercise 2: Using Variables (5 Marks)
#
# A body is launched into the air at an angle $\theta=25^\circ$ (compared to ground level) with initial velocity of $v_0=7.5$m/s. Assume an acceleration due to gravity of $g=9.81$ms$^{-2}$.
#
# Calculate the following:
#
# 1. Initial horizontal velocity $v_{\rm x,0}$ and vertical velocity $v_{\rm y,0}$. Do the NumPy trigonometric functions, e.g. `np.sin()` work with angles in degrees or radians? (Use an internet search to help you, if necessary). Can you find an easy way to convert between degrees and radians using NumPy?
# 2. Total time the body spends in the air, T. Remember that the body spends as much time going up as going down, so $v_{\rm y,0}=g T/2$.
# 3. Altitude of the body after $t_1=200$ms, $t_2=400$ms and $t_3=T$.  The relevant formula is $h=v_{\rm y,0} t-\frac{1}{2}g t^{2}$. You then just have to change the time and re-evaluate.
# 4. Distance from the launch position at times $t_1=200$ms, $t_2=400$ms and $t_3=T$, according to $d=\sqrt{x^2 + y^2}$ where $x=v_{\rm x,0}t$ and $y=v_{\rm y,0}t -gt^{2}/2$.
# 5. What is the maximum altitude?  At which distance from the launch position does the body hit the ground?
#
# N.B. You will come back to this exercise later on, so make sure you add clear comments to your code as a reminder to yourself of what it is doing!

# %%
# Write your set-up and answer question 1 here

'''
Ex2 and further, Body Launched at 25 deg. solution
24/09/26 - daniel mui
'''

#init vars and import modules
import numpy as np # first lecture he said it as num pee, i was hurt by this

# --- Given values, as we know RTFQ

theta_deg = 25.0      # launch angle in degrees
v0 = 7.5              # initial speed (m/s)
g = 9.81              # gravitational acceleration (m/s^2)

theta = np.radians(theta_deg) #as rad default for trig functions in numpy we must convert to rad.

# --- Q1 code now

vx0 = v0 * np.cos(theta)   # horizontal component
vy0 = v0 * np.sin(theta)   # vertical component
print('1. vx0 = {0:.2f} m/s, vy0 = {1:.2f} m/s'.format(vx0, vy0)) #we can use the same formatting as before in the error and debugging section

# alternatively we can use
# print(f'1. vx0 = {vx0:.2f} m/s, vy0 = {vy0:.2f} m/s'), which uses f string formatting, more modern and easier to read
# or we could use
# print('1. vx0 = %.2f m/s, vy0 = %.2f m/s' % (vx0, vy0)), which uses the slightly older % style formatting
# Out:
# 1. vx0 = 6.80 m/s, vy0 = 3.17 m/s

# %%
# Answer question 2 here
''' 
Time up = time down, 
so vy0 = g*T/2  
=>   T = 2*vy0/g 
'''
T = 2 * vy0 / g
print('2. Time in the air T = {0:.3f} s'.format(T)) #refer to the previous print formatting for more details and alternative ways to format the output.
# Out:
# 2. Time in the air T = 0.646 s

# %%
# Answer question 3 here
# init vars
t1 = 0.200   # convert ms to s
t2 = 0.400
t3 = T

#actual calc 

h1 = vy0*t1 - 0.5*g*t1**2
h2 = vy0*t2 - 0.5*g*t2**2
h3 = vy0*t3 - 0.5*g*t3**2   # should come out as 0, we could breakpoint here to check if it does, but we will just print it out instead because... well i mean look at it
print('3. h(t1) = {0:.3f} m, h(t2) = {1:.3f} m, h(T) = {2:.3f} m'.format(h1, h2, h3)) #refer to the previous print formatting for more details and alternative ways to format the output.
# Out:
# 3. h(t1) = 0.438 m, h(t2) = 0.483 m, h(T) = 0.000 m

# %%
# Answer question 4 here
#init var
x1, y1 = vx0*t1, vy0*t1 - g*t1**2/2 # i have nothing to say its the horizontal and vertical positions at time t1
x2, y2 = vx0*t2, vy0*t2 - g*t2**2/2 # same thing but for t2
x3, y3 = vx0*t3, vy0*t3 - g*t3**2/2 # and t3

#real calcs

d1 = np.sqrt(x1**2 + y1**2) #we can use the pythagorean theorem to calculate the distance from the origin to the point (x1, y1)
d2 = np.sqrt(x2**2 + y2**2)
d3 = np.sqrt(x3**2 + y3**2)
print('4. d(t1) = {0:.3f} m, d(t2) = {1:.3f} m, d(T) = {2:.3f} m'.format(d1, d2, d3)) #refer to the previous print formatting for more details and alternative ways to format the output.
# Out:
# 4. d(t1) = 1.428 m, d(t2) = 2.762 m, d(T) = 4.392 m

# %%
# Answer question 5 here
# Maximum altitude is reached at the top, at t = T/2

t_top = T / 2 #set the time at the top of the trajectory to be half the total time in the air

h_max = vy0*t_top - 0.5*g*t_top**2 #then we can use the same eq as before to calc the max alt, which is the vert pos @ time t_top

# Body lands at t = T, so the horizontal range is vx0 * T
landing_distance = vx0 * T
#print('5. Max altitude = {0:.3f} m, lands {1:.3f} m from the launch point'.format(h_max, landing_distance)) #we could also use f string here, blah blah blah see prior comments
#in fact why dont we
print(f'5. Max altitude = {h_max:.3f} m, lands {landing_distance:.3f} m from the launch point') #now you can refer to the prior parts on the other ways to do the out
# Out:
# 5. Max altitude = 0.512 m, lands 4.392 m from the launch point
